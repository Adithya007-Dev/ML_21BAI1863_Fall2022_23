# %% [markdown]
# <a href="https://colab.research.google.com/github/Adithya007-Dev/ML_21BAI1863_Fall2022_23/blob/main/LabAssignment_2_21BAI1863.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PART I**:
#
# Create a data frame as mentioned below,
# raw_data = {'first_name': ['Jason', np.nan, 'Tina', 'Jake', 'Amy'],
#         'last_name': ['Miller', np.nan, 'Ali', 'Milner', 'Cooze'],
#         'age': [42, np.nan, 36, 24, 73],
#         'sex': ['m', np.nan, 'f', 'm', 'f'],
#         'preTestScore': [4, np.nan, np.nan, 2, 3],
#         'postTestScore': [25, np.nan, np.nan, 62, 70]}

# %%
import numpy as np
import pandas as pd
raw_data = {'first_name': ['Jason', np.nan, 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', np.nan, 'Ali', 'Milner', 'Cooze'], 
        'age': [42, np.nan, 36, 24, 73], 
        'sex': ['m', np.nan, 'f', 'm', 'f'], 
        'preTestScore': [4, np.nan, np.nan, 2, 3],
        'postTestScore': [25, np.nan, np.nan, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'sex', 'preTestScore', 'postTestScore'])
df
# Out:
#   first_name last_name   age  sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0    m           4.0           25.0
# 1        NaN       NaN   NaN  NaN           NaN            NaN
# 2       Tina       Ali  36.0    f           NaN            NaN
# 3       Jake    Milner  24.0    m           2.0           62.0
# 4        Amy     Cooze  73.0    f           3.0           70.0

# %% [markdown]
# Drop the row, if any data contains “NaN” and Drop the row, where all the cells have “NaN”.

# %%
df1 = df.dropna()
df1
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
# Create a new column called “location” with all missing values.

# %%
df['location'] = np.nan
df
# Out:
#   first_name last_name   age  sex  preTestScore  postTestScore  location
# 0      Jason    Miller  42.0    m           4.0           25.0       NaN
# 1        NaN       NaN   NaN  NaN           NaN            NaN       NaN
# 2       Tina       Ali  36.0    f           NaN            NaN       NaN
# 3       Jake    Milner  24.0    m           2.0           62.0       NaN
# 4        Amy     Cooze  73.0    f           3.0           70.0       NaN

# %% [markdown]
# Drop column if they contains only a missing values

# %%
df = df.dropna(axis=1, how='all')
df
# Out:
#   first_name last_name   age  sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0    m           4.0           25.0
# 1        NaN       NaN   NaN  NaN           NaN            NaN
# 2       Tina       Ali  36.0    f           NaN            NaN
# 3       Jake    Milner  24.0    m           2.0           62.0
# 4        Amy     Cooze  73.0    f           3.0           70.0

# %% [markdown]
# Drop the rows that contain less than four observations

# %%
df = df.dropna(thresh=4)
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 2       Tina       Ali  36.0   f           NaN            NaN
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
# Fill all the data with missing values of “ZERO”.

# %%
df = df.fillna(0)
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 2       Tina       Ali  36.0   f           0.0            0.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
# Select the rows but ignore rows where any missing data points in a column “age” and “sex”.

# %%
df = df[(~df['age'].isna()) & (~df['sex'].isna())]
df
# Out:
#   first_name last_name   age sex  preTestScore  postTestScore
# 0      Jason    Miller  42.0   m           4.0           25.0
# 2       Tina       Ali  36.0   f           0.0            0.0
# 3       Jake    Milner  24.0   m           2.0           62.0
# 4        Amy     Cooze  73.0   f           3.0           70.0

# %% [markdown]
# **Part II**
#
# Read the file called "Data.csv"
# Apply the following lines of code and understand what is happening.
# X = dataSet.iloc[:,:-1].values     #dataSet is data frame object.
# y= dataSet.iloc[:,:3].values
# Apply imputer strategy on “Mean” to the features “Age” and “Salary”.

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-65b8a23d-2337-4068-b568-74ff44fcc89c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65b8a23d-2337-4068-b568-74ff44fcc89c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataSet = pd.read_csv('Data (1).csv', header=None)

X = dataSet.iloc[:,:-1].values 
y= dataSet.iloc[:,:3].values
print(X)
print(y)
# Out:
# [['Country' 'Age' 'Salary']
#  ['France' '44' '72000']
#  ['Spain' '27' '48000']
#  ['Germany' '30' '54000']
#  ['Spain' '38' '61000']
#  ['Germany' '40' nan]
#  ['France' '35' '58000']
#  ['Spain' nan '52000']
#  ['France' '48' '79000']
#  ['Germany' '50' '83000']
#  ['France' '37' '67000']]
# [['Country' 'Age' 'Salary']
#  ['France' '44' '72000']
#  ['Spain' '27' '48000']
#  ['Germany' '30' '54000']
#  ['Spain' '38' '61000']
#  ['Germany' '40' nan]
#  ['France' '35' '58000']
#  ['Spain' nan '52000']
#  ['France' '48' '79000']
#  ['Germany' '50' '83000']
#  ['France' '37' '67000']]

# %% [markdown]
# Apply imputer strategy on “Mean” to the features “Age” and “Salary”.

# %%
from sklearn.impute import SimpleImputer
df_dropna = pd.read_csv('Data (1).csv') 
print(df_dropna)

# create imputer instance with "mean" strategy
imputer = SimpleImputer(strategy='mean', missing_values=np.nan)
# dfData
imputer

# impute missing values in "age" columns
imputer =imputer.fit(df_dropna[['Age', 'Salary']])
df_dropna[['Age', 'Salary']] = imputer.transform(df_dropna[['Age', 'Salary']])
df_dropna
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %% [markdown]
# PART - III
#
# from sklearn.datasets import load_boston
#
# 1) Load the data set from the given URL
#
# data_url = "http://lib.stat.cmu.edu/datasets/boston"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# load the dataset from the URL
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2,:], raw_df.values[1::2,:3]])
df = pd.DataFrame(data)
df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE',
              'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# 2) Understand the data set and identify the columns

# %%
print(df.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# 3) Find the type of each columns in the given data set.

# %%
print(df.dtypes)
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %% [markdown]
# 4) Draw the box plot for the feature “DIS” and print the IQR for each column.

# %%
sns.boxplot(x=df['DIS'])
print(df.quantile([0.25, 0.5, 0.75]))
# Out:
#           CRIM    ZN  INDUS  CHAS    NOX      RM     AGE       DIS   RAD  \
# 0.25  0.082045   0.0   5.19   0.0  0.449  5.8855  45.025  2.100175   4.0
# 0.50  0.256510   0.0   9.69   0.0  0.538  6.2085  77.500  3.207450   5.0
# 0.75  3.677083  12.5  18.10   0.0  0.624  6.6235  94.075  5.188425  24.0
#
#         TAX  PTRATIO         B   LSTAT    MEDV
# 0.25  279.0    17.40  375.3775   6.950  17.025
# 0.50  330.0    19.05  391.4400  11.360  21.200
# 0.75  666.0    20.20  396.2250  16.955  25.000

# %% [markdown]
# 5) Draw the plot to visualize the correalaiton between each feature.

# %%
corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
# Out:
# <Axes: >

# %% [markdown]
# 6) Apply the histogram plot and find the inference out of it for the feature (PRICE).

# %%
sns.histplot(data=df, x="MEDV", kde=True)
plt.show()

# %% [markdown]
# 7) Draw the scatter plot for the number of rooms Vs. value of house

# %%
sns.scatterplot(data=df, x="RM", y="MEDV")
plt.show()
